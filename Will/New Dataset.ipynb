# %%
from careerjet_api_client import CareerjetAPIClient

cj  =  CareerjetAPIClient("en_GB");

result_json = cj.search({
                        'location'    : 'london',
                        'keywords'    : 'python',
                        'affid'       : '213e213hd12344552',
                        'user_ip'     : 'df',
                        'url'         : 'https://google.com',
                        'user_agent'  : 'fds'
                      });
result_json
# Out:
# {'jobs': [{'salary_min': '450',
#    'locations': 'Central London',
#    'salary_type': 'D',
#    'date': 'Fri, 26 Jul 2019 07:30:28 GMT',
#    'description': '<b>Python</b> Developer (RESTful API, Django, <b>Python</b>)   Want to work for one of the top 5 most recognisable brands in the... world that makes a profit of over £1.6 million per hour? Well my client is currently on the lookout for a <b>Python</b> Developer...',
#    'salary_currency_code': 'GBP',
#    'salary': '&pound;450 - 600 per day',
#    'site': '',
#    'url': 'http://jobviewtrack.com/en-gb/job-481a417d54100701495464061e0402081545066a390a5e4352432f200a1842184f130d136f565318/a0b098a7f98a9319cc8e5f353afdd9cd.html?affid=213e213hd12344552',
#    'title': 'Python Developer',
#    'salary_max': '600',
#    'company': 'Anson McCade'},
#   {'salary_min': '500',
#    'locations': 'Central London',
#    'salary_type': 'D',
#    'date': 'Fri, 26 Jul 2019 07:02:50 GMT',
#    'description': '<b>Python</b> Developer (RESTful API, Django, <b>Python</b>)   Interested in shaping the next generation of startups? Inventing...',
#    'salary_currency_code': 'GBP',
#    'salary': '&pound;500 - 600 per day',
#    'site': '',
#    'url': 'http://jobviewtrack.com/en-gb/job-4e13417d5410070149546409090f09084564111e0c1f455b585f2f34161a4f1b4e432c0b0f09024f763810074244530d6901190b4b1b50061a632a0d044e130749374f5d584142140a1c2535702a48250b11004c1b180c012b1a0b15/fa1958cfdccc9de6fa1286ad74454d2b.html?affid=213e213hd12344552',
#    'title': 'Python Developer (RESTful API, Django, Python)',
#    'salary_max': '600',
#    'company': 'Anson McCade'},
#   {'salary_min': '100000',
#    'locations': 'London',
#    'salary_type': 'Y',
#    'date': 'Wed, 24 Jul 2019 07:31:47 GMT',
#    'description': 'Senior <b>Python</b> Developer - Data Lakes   Senior <b>Python</b> Developer - A world-leading information provider... are looking for a talented and enthusiastic Senior <b>Python</b> Developer to build a new enterprise solution that collates and understands huge data...',
#    'salary_currency_code': 'GBP',
#    'salary': '&pound;100000 - 110000 per year',
#    'site': '',
#    'url': 'http://jobviewtrack.com/en-gb/job-1b49417e480a06015554701a1c0901094564111e0c1f455b585f2f34161a4f1b4e432c041802094f040d1b71794e534442164f2a4202450f07110b1567731106001c580b794c59056d2a460041432c041802094f040d1b721b190414195d/c951b105941a2332eb0aeb14683e989b.html?affid=213e213hd12344552',
#    'title': 'Senior Python Developer - Data Lakes',
#    'salary_max': '110000',
#    'company': 'Understanding Recruitment'},
#   {'salary_min': '60000',
#    'locations': 'London',
#    'salary_type': 'Y',
#    'date': 'Sat, 27 Jul 2019 07:56:12 GMT',
#    'description': '<b>Python</b> Developer / £60,000 - £80,000 +very good bonus and benefits package! / St. Paul’s, London   Working in the... a new and refined Agile Development team of Angular, DevOps and <b>Python</b> Developers in building out new Greenfield platforms...',
#    'salary_currency_code': 'GBP',
#    'salary': '&pound;60000 - 80000 per year',
#    'site': '',
#    'url': 'http://jobviewtrack.com/en-gb/job-1d1b417d54100701495464061e0402081545066a390a5e4352432f200a1842184f130d136f5657194d5c50/fa90722967e62ae0a91590348adcf9e3.html?affid=213e213hd12344552',
#    'title': 'Python Developer',
#    'salary_max': '80000',
#    'company': 'Franklin Bates Limited'},
#   {'salary_min': '65000',
#    'locations': 'North West London',
#    'salary_type': 'Y',
#    'date': 'Sat, 27 Jul 2019 07:51:36 GMT',
#    'description': 'DevOps Engineer London to £80k   DevOps Engineer (Linux Docker Kubernetes <b>Python</b> Ansible VMware). Innovative technology...',
#    'salary_currency_code': 'GBP',
#    'salary': '&pound;65000 - 80000 per year',
#    'site': '',
#    'url': 'http://jobviewtrack.com/en-gb/job-1e124161440a1a1607314e04010f0b02172222251e12584e1d6843030600421152612c0418281553542d0714434558485f66392350155206482d070910587624001d5f531d694812201e547511515f575751/ef2c1825e29b15635f15271f8b279cdb.html?affid=213e213hd12344552',
#    'title': 'DevOps Engineer Linux Python VMware',
#    'salary_max': '80000',
#    'company': 'Support Team'},
#   {'salary_min': '55000',
#    'locations': 'London - Feltham, Greater London',
#    'salary_type': 'Y',
#    'date': 'Sat, 27 Jul 2019 07:48:19 GMT',
#    'description': 'Test Engineer Uxbridge to £70k   Test Engineer (QA <b>Python</b> Automation Web Selenium Cucumber). Bring your unique talents...',
#    'salary_currency_code': 'GBP',
#    'salary': '&pound;55000 - 70000 per year',
#    'site': '',
#    'url': 'http://jobviewtrack.com/en-gb/job-4e1b417948171b4e621a470a06040b15457311040c1d435e502f79011c1a07314e04010f0b021722270d0516444248400d300a1d5376701a1c09010967651a0f001d4f4e4f2c1c565657134d22525b555d5454/d00a5bcda99421acd27b3ae00530e21a.html?affid=213e213hd12344552',
#    'title': 'Test Engineer Python Selenium Cucumber',
#    'salary_max': '70000',
#    'company': 'Client Server'},
#   {'salary_min': '90000',
#    'locations': 'London',
#    'salary_type': 'Y',
#    'date': 'Sat, 27 Jul 2019 07:13:18 GMT',
#    'description': 'Database Engineer London to £150k   Database Engineer (<b>Python</b> SQL Linux DBA). Are you an experienced Database Engineer...',
#    'salary_currency_code': 'GBP',
#    'salary': '&pound;90000 - 150000 per year',
#    'site': '',
#    'url': 'http://jobviewtrack.com/en-gb/job-1d1e4161440a1a1607314e04010f0b02172227392553797a712f7e35234e631554020a001d026764151c08114b58580d680a0807491145116a323f2b45651a0f001d4f4e4f2c1c565657134d/60ce5c3e8d9cd3786940118762e011c5.html?affid=213e213hd12344552',
#    'title': 'Database Engineer Python SQL Linux',
#    'salary_max': '150000',
#    'company': 'Data Team'},
#   {'salary_min': '70000',
#    'locations': 'North West London',
#    'salary_type': 'Y',
#    'date': 'Thu, 25 Jul 2019 07:38:15 GMT',
#    'description': 'Senior Data Engineer London to £80k   Senior Data Engineer (Linux <b>Python</b> ETL). Would you like to work on complex...',
#    'salary_currency_code': 'GBP',
#    'salary': '&pound;70000 - 80000 per year',
#    'site': '',
#    'url': 'http://jobviewtrack.com/en-gb/job-1e1a417e480a0601555464021c004e220b471d060c165829794c59054f2b4913490d0d041c4735590000061d286f5c594c442a00401d4e060d136c34004e1d071b536f455a4443010a1c2538490d1d194e220b471d060c16582a0c1f1a525658/20125d48fffdacda02d928af62e1e79c.html?affid=213e213hd12344552',
#    'title': 'Senior Data Engineer Linux Python ETL',
#    'salary_max': '80000',
#    'company': 'Data Team'},
#   {'salary_min': '500',
#    'locations': 'London',
#    'salary_type': 'D',
#    'date': 'Thu, 25 Jul 2019 07:09:56 GMT',
#    'description': 'Senior Data Engineer ( ETL / <b>Python</b> / Data Pipeline )  London  3-month initial contract  Daily rate: £500-£650 based... on experience  Immediate start   Senior Data Engineer ( ETL / <b>Python</b> / Data Pipelines ) with significant experience in ETL design...',
#    'salary_currency_code': 'GBP',
#    'salary': '&pound;500 - 650 per day',
#    'site': '',
#    'url': 'http://jobviewtrack.com/en-gb/job-494f417e480a0601555464021c004e220b471d060c165829794c59054f2b4913490d0d041c4735590000061d287b545d480806004254650d0f0800020052543b0c1d43444f2f7d0d1f0b4b1d4e06482400000c4e110d1b716e4a494c0d2101094e1a45061a605f555c194051/34111e5633bc8bf7f252f21817199e8f.html?affid=213e213hd12344552',
#    'title': 'Senior Data Engineer ( ETL / Python / Data Pipeline )',
#    'salary_max': '650',
#    'company': 'Venturi'},
#   {'locations': 'London',
#    'site': '',
#    'date': 'Fri, 05 Jul 2019 06:52:48 GMT',
#    'url': 'http://jobviewtrack.com/en-gb/job-1d1b417d54100701495464061e0402081545066a390a5e4352432f200a1842184f130d136f5657194d5c50/14022d9c5945efb7482f9543d34735e1.html?affid=213e213hd12344552',
#    'title': 'Python Developer',
#    'description': ' & Integration, and Testing.   We are currently seeking a top performing <b>Python</b> Developer with hands on experience in Data... Services requires an experienced <b>Python</b> Developer with Technical / Management skills in the area of business intelligence, data...',
#    'company': 'Capgemini',
#    'salary': ''},
#   {'salary_min': '450',
#    'locations': 'London',
#    'salary_type': 'D',
#    'date': 'Sat, 27 Jul 2019 07:59:35 GMT',
#    'description': '<b>Python</b> Developer (RESTful API, Django, <b>Python</b>) Want to work for one of the top 5 most recognisable brands in the world... that makes a profit of over £1.6 million per hour? Well my client is currently on the lookout for a <b>Python</b> Developer (RESTful API...',
#    'salary_currency_code': 'GBP',
#    'salary': '&pound;450 - 600 per day',
#    'site': '',
#    'url': 'http://jobviewtrack.com/en-gb/job-1d1b417d54100701495464061e0402081545066a390a5e4352432f200a1842184f130d136f5657194d5c50/d5a7361d7cf16b60422ecff8c3f7ef8c.html?affid=213e213hd12344552',
#    'title': 'Python Developer',
#    'salary_max': '600',
#    'company': 'Anson McCade'},
#   {'locations': 'London',
#    'site': '',
#    'date': 'Sat, 27 Jul 2019 07:58:12 GMT',
#    'url': 'http://jobviewtrack.com/en-gb/job-1d1b417d54100701495464061e0402081545066a390a5e4352432f200a1842184f130d136f5657194d5c50/02b34e5ab81bab0f2e9db4638fee4a17.html?affid=213e213hd12344552',
#    'title': 'Python Developer',
#    'description': 'Junior Developer/ <b>Python</b> Gradudate <b>Python</b> Developer Our client is looking for a Junior <b>python</b> developer who... finance industry and are only getting bigger. Requirements: Proficiency in <b>Python</b> Knowledge of <b>Python</b> frameworks such as Flask...',
#    'company': 'OHO Group',
#    'salary': ''},
#   {'locations': 'London',
#    'site': '',
#    'date': 'Sat, 27 Jul 2019 07:56:18 GMT',
#    'url': 'http://jobviewtrack.com/en-gb/job-184f416f4c07044e621a44432c041802094f040d1b717a524945420a4f2a4202450f07110b156762150b02536f45592f7d1d1b06481a22270d170b0b0a50111a68421812041914/9993d53ce977cfc77585ee253df5622b.html?affid=213e213hd12344552',
#    'title': 'Back End Developer (Mongo, Node, Python)',
#    'description': ' warehouse. An ideal background will comprise of <b>Python</b>, Node and Mongo DB / JavaScript technologies. This is a superb...',
#    'company': 'InterAct Consulting',
#    'salary': ''},
#   {'locations': 'London',
#    'site': '',
#    'date': 'Sat, 27 Jul 2019 07:55:37 GMT',
#    'url': 'http://jobviewtrack.com/en-gb/job-194e417e480a06015554701a1c0901094564111e0c1f455b585f2f34161a4f1b4e432c041802094f040d1b71794e534442164f2a4202450f07110b1567700d1c011c442979485b010301571152625953575e5119/dcde0b9d8bcdc6e91338cdc1decdc669.html?affid=213e213hd12344552',
#    'title': 'Senior Python Developer',
#    'description': ", by combining banking and accounting into one simple product. As an experienced <b>python</b> engineer your expertise will assist a growing... engineering team to help deliver an ambitious road map. You'll utilise your strong <b>python</b> development background to work...",
#    'company': 'LinuxRecruit',
#    'salary': ''},
#   {'salary_min': '65000',
#    'locations': 'London',
#    'salary_type': 'Y',
#    'date': 'Sat, 27 Jul 2019 07:52:34 GMT',
#    'description': 'Graduate/ Junior Developer (C#, Java, C++, <b>Python</b>), Strong Academics, Award Winning Hedge Fund, £65,000 + Bonus...',
#    'salary_currency_code': 'GBP',
#    'salary': '&pound;65000 per year',
#    'site': '',
#    'url': 'http://jobviewtrack.com/en-gb/job-.html?affid=213e213hd12344552',
#    'title': 'Graduate/ Junior Developer (C#, Java, C++, Python), Hedge Fund,£65,000',
#    'salary_max': '65000',
#    'company': 'Hunter Bond'},
#   {'locations': 'London',
#    'site': '',
#    'date': 'Sat, 27 Jul 2019 07:50:25 GMT',
#    'url': 'http://jobviewtrack.com/en-gb/job-1c1a417d54100701495464061e0402081545066a390a5e4352432f200a1842184f130d136c240c540d69584113120914/63ab7fec673e14b313a4d06f54ed373c.html?affid=213e213hd12344552',
#    'title': 'Python Developer InsurTech City of London',
#    'description': ' through utilising data. They are on the search for a <b>Python</b> developer to join the team on a permanent basis. As a <b>Python</b>...: -Strong proficiency with <b>Python</b> -Excellent ability to build Machine Learning models and algorithms -Analytical thinking...',
#    'company': 'TechAi',
#    'salary': ''},
#   {'locations': 'London',
#    'site': '',
#    'date': 'Sat, 27 Jul 2019 07:49:59 GMT',
#    'url': 'http://jobviewtrack.com/en-gb/job-1b4d417e480a06015554650d0f080002005276240c124e0b78434a0d010b420622221b120b1345651a0f001d4f4e4f2f7d080e1a411b520e482400000c4e110d1b71784e4d425f10060040546c0609056f5657194d5c50/63be8c156562b9fccbe54047c4676d3f.html?affid=213e213hd12344552',
#    'title': 'Senior Python Engineer Lead - Cross Asset Reporting Platform - Vice Pr',
#    'description': ' <b>Python</b>, Java, HTML5, JavaScript etc.  This exciting FO facing role involves working closely with our highly..., development, testing, deployment and support.     Strong development skills and experience using OO development (<b>Python</b>, Java or C...',
#    'company': 'JPMorgan Chase & Co.',
#    'salary': ''},
#   {'locations': 'London',
#    'site': '',
#    'date': 'Sat, 27 Jul 2019 07:48:05 GMT',
#    'url': 'http://jobviewtrack.com/en-gb/job-184d417d54100701495464061e040208154506482a1c445f4f4c4e106d3e5e00480c06412a0213451807191658297e4243101d0f440000270d170b0b0a50111a6b23535f554243442c01490052020b156c371c541c0707721b190414195d/c5f2e9f12d7316db7ebcc84583913ad5.html?affid=213e213hd12344552',
#    'title': 'Python Developer - Permanent or Contract',
#    'description': '<b>Python</b> Developer - Permanent or Contract This London based propriatory trading firm is looking to recruit a highly... skilled <b>Python</b> Developer on a permanent basis. This is a <b>Python</b> Software Engineering role with primary focus on the...',
#    'company': 'McGregor Boyall Associates',
#    'salary': ''},
#   {'locations': 'London',
#    'site': '',
#    'date': 'Sat, 27 Jul 2019 07:47:21 GMT',
#    'url': 'http://jobviewtrack.com/en-gb/job-1b4a414e0d074f0d07170033111506080b223c0d0d144f0b7b5843004f0d2527450d010e1c47060031060e1a444e585f2f370a004e1b52432c001a0645651a0f001d4f4e4f2f69051b0f07314e04010f0b02170024111d1b45453c1c1f5d565a1e/fb8906ee38fef329b59a57ba4033e198.html?affid=213e213hd12344552',
#    'title': 'Senior Python/C# Data Engineer, Hedge Fund',
#    'description': 'Senior <b>Python</b>/C# Data Engineer, Hedge Fund My client are a leading hedge fund that are headquartered in London... and enthusiastic candidate with strong programming in either C# or <b>Python</b> and a real passion for working with large datasets and on new...',
#    'company': 'TEKsystems',
#    'salary': ''},
#   {'locations': 'London',
#    'site': '',
#    'date': 'Sat, 27 Jul 2019 07:45:54 GMT',
#    'url': 'http://jobviewtrack.com/en-gb/job-1a4a417d54100701495464061e0402081545066a390a5e4352432f200a1842184f130d136c210c4e000d0a1b2b1a0f14145056/ff4e15649c16d9eca1a923f4b9b6b489.html?affid=213e213hd12344552',
#    'title': 'Python Developer - FinTech',
#    'description': '<b>Python</b> Developer - <b>Python</b>, S3, SQL, Flask, Git, Elastic Search <b>Python</b> Developer for a FinTech software house in London... is required. They currently have multiple products out on the market with financial services and need a <b>Python</b> expert to join their Data...',
#    'company': 'Pioneer Search',
#    'salary': ''}],
#  'hits': 6132,
#  'response_time': 0.0619029998779297,
#  'type': 'JOBS',
#  'pages': 307}
